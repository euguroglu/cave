# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/cave/blob/master/Seaborn_plots_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading seaborn built in datasets

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Example 1 Distribution
sns.distplot(tips['total_bill'],kde=False,bins=40)
sns.set(style='darkgrid')

# %%
#Example 2 Jointplot (default scatter)
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
#Example 3 Jointplot (hex)
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
#Example 3 Jointplot (regression)
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
#Example 4 Jointplot (kde)
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
#Example 5 Pairplot
sns.pairplot(tips,hue='sex')

# %%
#Example 5 Rugplot
sns.rugplot(tips['total_bill'])
