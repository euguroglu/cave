# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/cave/blob/master/Seaborn_lib_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris Project

# %% [markdown]
# ## Data Exploration and Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
import sys
print(sys.version)
# Out:
# 1.18.5
# 1.0.5
# 0.10.1
# 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0]

# %% [markdown]
# # Iris Data from Seaborn

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Visualisation

# %%
sns.pairplot(iris, hue='species', height=3, aspect=1);

# %%
iris.hist(edgecolor='black', linewidth=1.2, figsize=(12,8));
plt.show();

# %%
plt.figure(figsize=(12,8));
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=iris);

# %%
iris.boxplot(by='species', figsize=(12,8));

# %%
pd.plotting.scatter_matrix(iris, figsize=(12,10))
plt.show()

# %%
sns.pairplot(iris, hue="species", diag_kind="kde");

# %% [markdown]
# ***
