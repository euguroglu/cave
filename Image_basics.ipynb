# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/cave/blob/master/Image_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
image = io.imread('https://media.giphy.com/media/pynZagVcYxVUk/giphy.gif')
plt.imshow(image)

# %%
image.shape
# Out:
# (250, 250, 4)

# %%
image[0][0]
# Out:
# array([229, 215, 203, 255], dtype=uint8)

# %%
image[50][125]
# Out:
# array([230, 184, 141, 255], dtype=uint8)

# %%
plt.imshow(image[:,::-1])

# %%
plt.imshow(image[::-1])

# %%
plt.imshow(image[50:100,100:150])
