# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/cave/blob/master/Seaborn_plots_tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
sns.set_style('darkgrid')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# Axis size definition

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(ax=ax,x='day',y='total_bill',data=tips,hue='sex',split=True)

# %% [markdown]
# ## Strip plot

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Swarm plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# ## Swarm + Violin plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
sns.violinplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# ## Factor plot

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
